# %%
import pandas as pd

# %%
datos = {
"usuario":["Ana","Luis","Martha","Carolina","Sofia","Pedro","Elena","Diego"],
"edad": [22,35,28,40,19,31,26,45],
"ciudad": ["CDMX", "Monterrey","Guadalajara","Puebla","Cancún","Merida","Tijuana","Veracruz"],
"compras_realizadas": [5,12,3,29,1,7,4,15],
"activo": [True, False, True, True, False,True, False, True],
"fecha_registro": ["2026-01-10", "2026-01-12","2025-02-10","2026-01-10", "2026-01-12","2025-02-10","2026-01-12","2025-02-10"]
}

# %%
df =pd.DataFrame(datos)

# %%
print(df)
# Out:
#     usuario  edad       ciudad  compras_realizadas  activo fecha_registro
# 0       Ana    22         CDMX                   5    True     2026-01-10
# 1      Luis    35    Monterrey                  12   False     2026-01-12
# 2    Martha    28  Guadalajara                   3    True     2025-02-10
# 3  Carolina    40       Puebla                  29    True     2026-01-10
# 4     Sofia    19       Cancún                   1   False     2026-01-12
# 5     Pedro    31       Merida                   7    True     2025-02-10
# 6     Elena    26      Tijuana                   4   False     2026-01-12
# 7     Diego    45     Veracruz                  15    True     2025-02-10

# %%
cantidad = 1000000

# %%
import random

# %%
nombres= ["Ana","Luis","Martha","Carolina","Sofia","Pedro","Elena","Diego"]
ciudades = ["CDMX", "Monterrey","Guadalajara","Puebla","Cancún","Merida","Tijuana","Veracruz"]
categorias = ["Tecnologias","Ropa","Hogar","Videojuegos","Deportes","Calzado","Comida"]

# %%
dfMillon = pd.DataFrame({
    "nombre" : [random.choice(nombres) for _ in range(cantidad)],
    "edad" : [random.randint(18,70) for _ in range (cantidad)],
    "salario": [round (random.uniform(5000,50000),2) for _ in range (cantidad) ],
    "activo": [random.choice([True,False]) for _ in range (cantidad)],
    "categoria": [random.choice(categorias) for _ in range (cantidad)],
    "ciudad": [random.choice(ciudades) for _ in range (cantidad)],
    "anio_registro": [random.randint(2020,2026) for _ in range (cantidad)]
})

# %%
dfMillion.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 dfMillion.shape
#
# NameError: name 'dfMillion' is not defined

# %%
dfMillon.shape
# Out:
# (1000000, 7)

# %%
dfMillon.dtypes
# Out:
# nombre            object
# edad               int64
# salario          float64
# activo              bool
# categoria         object
# ciudad            object
# anio_registro      int64
# dtype: object

# %%
dfMillon.memory_usage(deep=True)
# Out:
# Index                  72
# nombre           30127447
# edad              8000000
# salario           8000000
# activo            1000000
# categoria        32428944
# ciudad           33119556
# anio_registro     8000000
# dtype: int64

# %%
dfMillon.memory_usage(deep=True).sum()/1024**2
# Out:
# np.float64(115.08561992645264)

# %%
import shutil

# %%
shutil.copytree("Extracción de datos", r"C:\Users\brenr\Documents\GitHub\ECBD-Brenda")
# Out:
# 'C:\\Users\\brenr\\Documents\\GitHub\\ECBD-Brenda'

# %%
import os
os.getcwd()
# Out:
# '/drive/notebooks'
